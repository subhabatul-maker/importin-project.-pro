# %% [markdown]
# <a href="https://colab.research.google.com/github/subhabatul-maker/importin-project.-pro/blob/main/importin_project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional display setting
pd.set_option("display.max_columns", None)

# %%
# Step 2: Data Collection

# Creating a sample student dataset

data = {
    "Student_ID": [101, 102, 103, 104, 105, 106, 107, 108],
    "Name": ["Rahul", "Madhumita", "Sara", "Amit", "Priya", "John", "Riya", "Arjun"],
    "Gender": ["Male", "Female", "Female", "Male", "Female", "Male", "Female", "Male"],
    "Math": [85, 92, 78, np.nan, 88, 76, 95, 67],
    "Science": [90, 89, np.nan, 72, 85, 80, 98, 70],
    "English": [88, 94, 79, 75, np.nan, 82, 96, 68],
    "Attendance": [92, 96, 85, 78, 88, 80, 98, np.nan],
    "Study_Hours": [3.5, 5.0, 2.5, 2.0, 4.0, 3.0, 6.0, 1.5]
}

df = pd.DataFrame(data)

print("========== ORIGINAL DATASET ==========")
print(df)
# Out:
# ========== ORIGINAL DATASET ==========
#    Student_ID       Name  Gender  Math  Science  English  Attendance  \
# 0         101      Rahul    Male  85.0     90.0     88.0        92.0
# 1         102  Madhumita  Female  92.0     89.0     94.0        96.0
# 2         103       Sara  Female  78.0      NaN     79.0        85.0
# 3         104       Amit    Male   NaN     72.0     75.0        78.0
# 4         105      Priya  Female  88.0     85.0      NaN        88.0
# 5         106       John    Male  76.0     80.0     82.0        80.0
# 6         107       Riya  Female  95.0     98.0     96.0        98.0
# 7         108      Arjun    Male  67.0     70.0     68.0         NaN
#
#    Study_Hours
# 0          3.5
# 1          5.0
# 2          2.5
# 3          2.0
# 4          4.0
# 5          3.0
# 6          6.0
# 7          1.5

# %%
# Step 3: Basic Information
# ================================
print("\n========== DATASET INFO ==========")
print(df.info())

print("\n========== FIRST 5 ROWS ==========")
print(df.head())

print("\n========== LAST 5 ROWS ==========")
print(df.tail())

print("\n========== SHAPE OF DATASET ==========")
print("Rows, Columns:", df.shape)

print("\n========== COLUMN NAMES ==========")
print(df.columns)
# Out:
# ========== DATASET INFO ==========
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Student_ID   8 non-null      int64
#  1   Name         8 non-null      object
#  2   Gender       8 non-null      object
#  3   Math         7 non-null      float64
#  4   Science      7 non-null      float64
#  5   English      7 non-null      float64
#  6   Attendance   7 non-null      float64
#  7   Study_Hours  8 non-null      float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 644.0+ bytes
# None
#
# ========== FIRST 5 ROWS ==========
#    Student_ID       Name  Gender  Math  Science  English  Attendance  \
# 0         101      Rahul    Male  85.0     90.0     88.0        92.0
# 1         102  Madhumita  Female  92.0     89.0     94.0        96.0
# 2         103       Sara  Female  78.0      NaN     79.0        85.0
# 3         104       Amit    Male   NaN     72.0     75.0        78.0
# 4         105      Priya  Female  88.0     85.0      NaN        88.0
#
#    Study_Hours
# 0          3.5
# 1          5.0
# 2          2.5
# 3          2.0
# 4          4.0
#
# ========== LAST 5 ROWS ==========
#    Student_ID   Name  Gender  Math  Science  English  Attendance  Study_Hours
# 3         104   Amit    Male   NaN     72.0     75.0        78.0          2.0
# 4         105  Priya  Female  88.0     85.0      NaN        88.0          4.0
# 5         106   John    Male  76.0     80.0     82.0        80.0          3.0
# 6         107   Riya  Female  95.0     98.0     96.0        98.0          6.0
# 7         108  Arjun    Male  67.0     70.0     68.0         NaN          1.5
#
# ========== SHAPE OF DATASET ==========
# Rows, Columns: (8, 8)
#
# ========== COLUMN NAMES ==========
# Index(['Student_ID', 'Name', 'Gender', 'Math', 'Science', 'English',
#        'Attendance', 'Study_Hours'],
#       dtype='object')

# %%
# Step 4: Check Missing Values

print("\n========== MISSING VALUES ==========")
print(df.isnull().sum())
# Out:
# ========== MISSING VALUES ==========
# Student_ID     0
# Name           0
# Gender         0
# Math           1
# Science        1
# English        1
# Attendance     1
# Study_Hours    0
# dtype: int64

# %%
# Step 5: Data Preprocessing

# Filling missing numeric values with column mean

df["Math"].fillna(df["Math"].mean(), inplace=True)
df["Science"].fillna(df["Science"].mean(), inplace=True)
df["English"].fillna(df["English"].mean(), inplace=True)
df["Attendance"].fillna(df["Attendance"].mean(), inplace=True)

print("\n========== DATASET AFTER FILLING MISSING VALUES ==========")
print(df)

print("\n========== MISSING VALUES AFTER CLEANING ==========")
print(df.isnull().sum())
# Out:
# ========== DATASET AFTER FILLING MISSING VALUES ==========
#    Student_ID       Name  Gender  Math    Science    English  Attendance  \
# 0         101      Rahul    Male  85.0  90.000000  88.000000   92.000000
# 1         102  Madhumita  Female  92.0  89.000000  94.000000   96.000000
# 2         103       Sara  Female  78.0  83.428571  79.000000   85.000000
# 3         104       Amit    Male  83.0  72.000000  75.000000   78.000000
# 4         105      Priya  Female  88.0  85.000000  83.142857   88.000000
# 5         106       John    Male  76.0  80.000000  82.000000   80.000000
# 6         107       Riya  Female  95.0  98.000000  96.000000   98.000000
# 7         108      Arjun    Male  67.0  70.000000  68.000000   88.142857
#
#    Study_Hours
# 0          3.5
# 1          5.0
# 2          2.5
# 3          2.0
# 4          4.0
# 5          3.0
# 6          6.0
# 7          1.5
#
# ========== MISSING VALUES AFTER CLEANING ==========
# Student_ID     0
# Name           0
# Gender         0
# Math           0
# Science        0
# English        0
# Attendance     0
# Study_Hours    0
# dtype: int64
# /tmp/ipykernel_451/2335556313.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Math"].fillna(df["Math"].mean(), inplace=True)
# /tmp/ipykernel_451/2335556313.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Science"].fillna(df["Science"].mean(), inplace=True)
# /tmp/ipykernel_451/2335556313.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["English"].fillna(df["English"].mean(), inplace=True)
# /tmp/ipykernel_451/2335556313.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Attendance"].fillna(df["Attendance"].mean(), inplace=True)

# %%
# Step 6: Add New Columns
# ================================
# Total and Average marks

df["Total"] = df["Math"] + df["Science"] + df["English"]
df["Average"] = df["Total"] / 3

# Grade calculation
def assign_grade(avg):
    if avg >= 90:
        return "A+"
    elif avg >= 80:
        return "A"
    elif avg >= 70:
        return "B"
    elif avg >= 60:
        return "C"
    else:
        return "D"

df["Grade"] = df["Average"].apply(assign_grade)

print("\n========== DATASET WITH TOTAL, AVERAGE, GRADE ==========")
print(df)
# Out:
# ========== DATASET WITH TOTAL, AVERAGE, GRADE ==========
#    Student_ID       Name  Gender  Math    Science    English  Attendance  \
# 0         101      Rahul    Male  85.0  90.000000  88.000000   92.000000
# 1         102  Madhumita  Female  92.0  89.000000  94.000000   96.000000
# 2         103       Sara  Female  78.0  83.428571  79.000000   85.000000
# 3         104       Amit    Male  83.0  72.000000  75.000000   78.000000
# 4         105      Priya  Female  88.0  85.000000  83.142857   88.000000
# 5         106       John    Male  76.0  80.000000  82.000000   80.000000
# 6         107       Riya  Female  95.0  98.000000  96.000000   98.000000
# 7         108      Arjun    Male  67.0  70.000000  68.000000   88.142857
#
#    Study_Hours       Total    Average Grade
# 0          3.5  263.000000  87.666667     A
# 1          5.0  275.000000  91.666667    A+
# 2          2.5  240.428571  80.142857     A
# 3          2.0  230.000000  76.666667     B
# 4          4.0  256.142857  85.380952     A
# 5          3.0  238.000000  79.333333     B
# 6          6.0  289.000000  96.333333    A+
# 7          1.5  205.000000  68.333333     C

# %%
# Step 7: Descriptive Statistics
# ================================
print("\n========== DESCRIPTIVE STATISTICS ==========")
print(df.describe())
# Out:
# ========== DESCRIPTIVE STATISTICS ==========
#        Student_ID       Math    Science    English  Attendance  Study_Hours  \
# count     8.00000   8.000000   8.000000   8.000000    8.000000     8.000000
# mean    104.50000  83.000000  83.428571  83.142857   88.142857     3.437500
# std       2.44949   9.133924   9.348142   9.417743    7.099871     1.522158
# min     101.00000  67.000000  70.000000  68.000000   78.000000     1.500000
# 25%     102.75000  77.500000  78.000000  78.000000   83.750000     2.375000
# 50%     104.50000  84.000000  84.214286  82.571429   88.071429     3.250000
# 75%     106.25000  89.000000  89.250000  89.500000   93.000000     4.250000
# max     108.00000  95.000000  98.000000  96.000000   98.000000     6.000000
#
#             Total    Average
# count    8.000000   8.000000
# mean   249.571429  83.190476
# std     26.757849   8.919283
# min    205.000000  68.333333
# 25%    236.000000  78.666667
# 50%    248.285714  82.761905
# 75%    266.000000  88.666667
# max    289.000000  96.333333

# %%
# Step 8: Top Performer

topper = df.loc[df["Average"].idxmax()]

print("\n========== TOPPER STUDENT ==========")
print("Name:", topper["Name"])
print("Average Marks:", round(topper["Average"], 2))
print("Grade:", topper["Grade"])
# Out:
# ========== TOPPER STUDENT ==========
# Name: Riya
# Average Marks: 96.33
# Grade: A+

# %%
# Step 9: Students with High Attendance

high_attendance = df[df["Attendance"] > 90]

print("\n========== STUDENTS WITH ATTENDANCE > 90 ==========")
print(high_attendance[["Name", "Attendance"]])
# Out:
# ========== STUDENTS WITH ATTENDANCE > 90 ==========
#         Name  Attendance
# 0      Rahul        92.0
# 1  Madhumita        96.0
# 6       Riya        98.0

# %%
# Step 10: Students with Average > 80
# ================================
high_performers = df[df["Average"] > 80]

print("\n========== STUDENTS WITH AVERAGE > 80 ==========")
print(high_performers[["Name", "Average", "Grade"]])
# Out:
# ========== STUDENTS WITH AVERAGE > 80 ==========
#         Name    Average Grade
# 0      Rahul  87.666667     A
# 1  Madhumita  91.666667    A+
# 2       Sara  80.142857     A
# 4      Priya  85.380952     A
# 6       Riya  96.333333    A+

# %%
# Step 11: Group By Gender
# ================================
gender_avg = df.groupby("Gender")[["Math", "Science", "English", "Average"]].mean()

print("\n========== AVERAGE MARKS BY GENDER ==========")
print(gender_avg)
# Out:
# ========== AVERAGE MARKS BY GENDER ==========
#          Math    Science    English    Average
# Gender
# Female  88.25  88.857143  88.035714  88.380952
# Male    77.75  78.000000  78.250000  78.000000

# %%
# Step 12: Sorting
# ================================
sorted_df = df.sort_values(by="Average", ascending=False)

print("\n========== STUDENTS SORTED BY AVERAGE MARKS ==========")
print(sorted_df[["Name", "Average", "Grade"]])
# Out:
# ========== STUDENTS SORTED BY AVERAGE MARKS ==========
#         Name    Average Grade
# 6       Riya  96.333333    A+
# 1  Madhumita  91.666667    A+
# 0      Rahul  87.666667     A
# 4      Priya  85.380952     A
# 2       Sara  80.142857     A
# 5       John  79.333333     B
# 3       Amit  76.666667     B
# 7      Arjun  68.333333     C

# %%
# Step 13: Visualization - Bar Chart
# ================================
plt.figure(figsize=(10, 5))
plt.bar(df["Name"], df["Average"])
plt.title("Student Average Marks")
plt.xlabel("Student Name")
plt.ylabel("Average Marks")
plt.xticks(rotation=45)
plt.show()

# %%
# Step 14: Visualization - Line Chart
# ================================
plt.figure(figsize=(10, 5))
plt.plot(df["Name"], df["Attendance"], marker='o')
plt.title("Student Attendance")
plt.xlabel("Student Name")
plt.ylabel("Attendance")
plt.xticks(rotation=45)
plt.show()

# %%
# Step 15: Visualization - Histogram
# ================================
plt.figure(figsize=(8, 5))
plt.hist(df["Average"], bins=5, edgecolor="black")
plt.title("Distribution of Average Marks")
plt.xlabel("Average Marks")
plt.ylabel("Frequency")
plt.show()

# %%
# Step 16: Visualization - Pie Chart
# ================================
grade_counts = df["Grade"].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(grade_counts, labels=grade_counts.index, autopct="%1.1f%%", startangle=90)
plt.title("Grade Distribution")
plt.show()

# %%
# Step 17: Seaborn Count Plot
# ================================
plt.figure(figsize=(8, 5))
sns.countplot(x="Grade", data=df)
plt.title("Count of Students by Grade")
plt.show()

# %%
# Step 18: Seaborn Box Plot
# ================================
plt.figure(figsize=(8, 5))
sns.boxplot(x="Gender", y="Average", data=df)
plt.title("Average Marks by Gender")
plt.show()

# %%
# Step 19: Seaborn Scatter Plot
# ================================
plt.figure(figsize=(8, 5))
sns.scatterplot(x="Study_Hours", y="Average", hue="Gender", data=df, s=100)
plt.title("Study Hours vs Average Marks")
plt.show()

# %%
# Step 20: Correlation Heatmap
# ================================
numeric_df = df.select_dtypes(include=np.number)

plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Step 21: Save Cleaned Dataset
# ================================
df.to_csv("cleaned_student_performance.csv", index=False)
print("\nCleaned dataset saved as 'cleaned_student_performance.csv'")
# Out:
# Cleaned dataset saved as 'cleaned_student_performance.csv'

# %%
# Step 22: Final Output
# ================================
print("\n========== FINAL CLEANED DATASET ==========")
print(df)
# Out:
# ========== FINAL CLEANED DATASET ==========
#    Student_ID       Name  Gender  Math    Science    English  Attendance  \
# 0         101      Rahul    Male  85.0  90.000000  88.000000   92.000000
# 1         102  Madhumita  Female  92.0  89.000000  94.000000   96.000000
# 2         103       Sara  Female  78.0  83.428571  79.000000   85.000000
# 3         104       Amit    Male  83.0  72.000000  75.000000   78.000000
# 4         105      Priya  Female  88.0  85.000000  83.142857   88.000000
# 5         106       John    Male  76.0  80.000000  82.000000   80.000000
# 6         107       Riya  Female  95.0  98.000000  96.000000   98.000000
# 7         108      Arjun    Male  67.0  70.000000  68.000000   88.142857
#
#    Study_Hours       Total    Average Grade
# 0          3.5  263.000000  87.666667     A
# 1          5.0  275.000000  91.666667    A+
# 2          2.5  240.428571  80.142857     A
# 3          2.0  230.000000  76.666667     B
# 4          4.0  256.142857  85.380952     A
# 5          3.0  238.000000  79.333333     B
# 6          6.0  289.000000  96.333333    A+
# 7          1.5  205.000000  68.333333     C

# %%
# Create Simple Dataset

import pandas as pd

data = {
    "Name": ["Rahul", "Madhu", "Sara", "Amit"],
    "Age": [20, 22, 21, 23],
    "Marks": [85, 92, 78, 88],
    "Attendance": [90, 95, 80, 85]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Marks  Attendance
# 0  Rahul   20     85          90
# 1  Madhu   22     92          95
# 2   Sara   21     78          80
# 3   Amit   23     88          85

# %%
# Missing Values Example

import pandas as pd
import numpy as np

data = {
    "Name": ["Rahul", "Madhu", "Sara", "Amit"],
    "Marks": [85, np.nan, 78, 88],
    "Attendance": [90, 95, np.nan, 85]
}

df = pd.DataFrame(data)
print("Original Data:")
print(df)

print("\nMissing Values:")
print(df.isnull().sum())

df["Marks"].fillna(df["Marks"].mean(), inplace=True)
df["Attendance"].fillna(df["Attendance"].mean(), inplace=True)

print("\nCleaned Data:")
print(df)
# Out:
# Original Data:
#     Name  Marks  Attendance
# 0  Rahul   85.0        90.0
# 1  Madhu    NaN        95.0
# 2   Sara   78.0         NaN
# 3   Amit   88.0        85.0
#
# Missing Values:
# Name          0
# Marks         1
# Attendance    1
# dtype: int64
#
# Cleaned Data:
#     Name      Marks  Attendance
# 0  Rahul  85.000000        90.0
# 1  Madhu  83.666667        95.0
# 2   Sara  78.000000        90.0
# 3   Amit  88.000000        85.0
# /tmp/ipykernel_451/3137915680.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Marks"].fillna(df["Marks"].mean(), inplace=True)
# /tmp/ipykernel_451/3137915680.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Attendance"].fillna(df["Attendance"].mean(), inplace=True)

# %%
# Remove Duplicates

import pandas as pd

data = {
    "Name": ["Rahul", "Rahul", "Sara", "Amit"],
    "Marks": [85, 85, 78, 88]
}

df = pd.DataFrame(data)
print("Before removing duplicates:")
print(df)

df = df.drop_duplicates()

print("\nAfter removing duplicates:")
print(df)
# Out:
# Before removing duplicates:
#     Name  Marks
# 0  Rahul     85
# 1  Rahul     85
# 2   Sara     78
# 3   Amit     88
#
# After removing duplicates:
#     Name  Marks
# 0  Rahul     85
# 2   Sara     78
# 3   Amit     88

# %%
# Matplotlib Bar Chart

import matplotlib.pyplot as plt

students = ["Rahul", "Madhu", "Sara", "Amit"]
marks = [85, 92, 78, 88]

plt.figure(figsize=(8, 5))
plt.bar(students, marks)
plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
# Line Chart

import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5]
sales = [200, 250, 300, 280, 350]

plt.figure(figsize=(8, 5))
plt.plot(days, sales, marker='o', color='red')
plt.title("Daily Sales")
plt.xlabel("Day")
plt.ylabel("Sales")
plt.show()

# %%
# Histogram

import matplotlib.pyplot as plt

marks = [85, 92, 78, 88, 90, 76, 84, 91, 87, 89]

plt.figure(figsize=(8, 5))
plt.hist(marks, bins=5, edgecolor='black')
plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
# Seaborn Count Plot

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.DataFrame({
    "Department": ["AI", "AI", "ML", "DS", "DS", "AI", "ML"]
})

plt.figure(figsize=(7, 5))
sns.countplot(x="Department", data=data)
plt.title("Department Count")
plt.show()

# %%
# Seaborn Heatmap

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.DataFrame({
    "Marks": [85, 92, 78, 88],
    "Attendance": [90, 95, 80, 85],
    "StudyHours": [3, 5, 2, 4]
})

plt.figure(figsize=(6, 4))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])
print("Array:", arr)
print("Mean:", np.mean(arr))
print("Sum:", np.sum(arr))
print("Max:", np.max(arr))
print("Min:", np.min(arr))
# Out:
# Array: [10 20 30 40 50]
# Mean: 30.0
# Sum: 150
# Max: 50
# Min: 10

# %%
# 2D Array

import numpy as np

matrix = np.array([[1, 2, 3], [4, 5, 6]])
print(matrix)
print("Shape:", matrix.shape)
# Out:
# [[1 2 3]
#  [4 5 6]]
# Shape: (2, 3)

# %%
# Pandas Basics

import pandas as pd

data = {
    "Name": ["Rahul", "Madhu", "Sara"],
    "Marks": [85, 92, 78]
}

df = pd.DataFrame(data)
print(df)
print("\n Marks Column:")
print(df["Marks"])
# Out:
#     Name  Marks
# 0  Rahul     85
# 1  Madhu     92
# 2   Sara     78
#
#  Marks Column:
# 0    85
# 1    92
# 2    78
# Name: Marks, dtype: int64

# %%
# Filter Data

import pandas as pd

data = {
    "Name": ["Rahul", "Madhu", "Sara", "Amit"],
    "Marks": [85, 92, 78, 88]
}

df = pd.DataFrame(data)
high_marks = df[df["Marks"] > 80]
print(high_marks)
# Out:
#     Name  Marks
# 0  Rahul     85
# 1  Madhu     92
# 3   Amit     88
